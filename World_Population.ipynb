# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\DELL\Downloads\world_population.csv',encoding='Unicode escape')

# %%
df.shape
# Out:
# (234, 17)

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (kmÃÂ²)',
#        'Density (per kmÃÂ²)', 'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (kmÃÂ²)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (kmÃÂ²)                  0
# Density (per kmÃÂ²)           0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country/Territory               object
# Capital                         object
# Continent                       object
# 2022 Population                  int64
# 2020 Population                  int64
# 2015 Population                  int64
# 2010 Population                  int64
# 2000 Population                  int64
# 1990 Population                  int64
# 1980 Population                  int64
# 1970 Population                  int64
# Area (kmÃÂ²)                    int64
# Density (per kmÃÂ²)           float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
#Checking the Unique Values
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country/Territory              234
# Capital                        234
# Continent                        6
# 2022 Population                234
# 2020 Population                234
# 2015 Population                234
# 2010 Population                234
# 2000 Population                234
# 1990 Population                234
# 1980 Population                234
# 1970 Population                234
# Area (kmÃÂ²)                  233
# Density (per kmÃÂ²)           234
# Growth Rate                    180
# World Population Percentage     70
# dtype: int64

# %%
#keep 2 digit after decimal
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara       El AaiÃÂºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
#filtering out the numeric values
df.select_dtypes('number')
# Out:
#      Rank  2022 Population  2020 Population  2015 Population  2010 Population  \
# 0      36         41128771         38972230         33753499         28189672
# 1     138          2842321          2866849          2882481          2913399
# 2      34         44903225         43451666         39543154         35856344
# 3     213            44273            46189            51368            54849
# 4     203            79824            77700            71746            71519
# ..    ...              ...              ...              ...              ...
# 229   226            11572            11655            12182            13142
# 230   172           575986           556048           491824           413296
# 231    46         33696614         32284046         28516545         24743946
# 232    63         20017675         18927715         16248230         13792086
# 233    74         16320537         15669666         14154937         12839771
#
# ...

# %%
#filtering the string values
df.select_dtypes('object')
# Out:
#     CCA3  Country/Territory           Capital Continent
# 0    AFG        Afghanistan             Kabul      Asia
# 1    ALB            Albania            Tirana    Europe
# 2    DZA            Algeria           Algiers    Africa
# 3    ASM     American Samoa         Pago Pago   Oceania
# 4    AND            Andorra  Andorra la Vella    Europe
# ..   ...                ...               ...       ...
# 229  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230  ESH     Western Sahara       El AaiÃÂºn    Africa
# 231  YEM              Yemen             Sanaa      Asia
# 232  ZMB             Zambia            Lusaka    Africa
# 233  ZWE           Zimbabwe            Harare    Africa
#
# [234 rows x 4 columns]

# %%
#Sorting the data on the basis of Population percentage
df.sort_values(by='World Population Percentage',ascending=False).head()
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
#Continent-wise Population Ratio
df.groupby('Continent').mean('numeric').sort_values(by='2022 Population',ascending=False)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      94427665.48      93261730.70      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25030367.23      23871435.26      21071972.67
# North America 160.93      15007403.40      14855914.82      14259596.25
# Europe        124.50      14862950.76      14915843.92      14830712.16
# Oceania       188.52       1958198.00       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               84400826.54      74701792.08      64211271.54
# South America      28077017.86      24973877.29      21224743.93
# Africa             18512773.19      14367474.25      11195625.07
# North America      13568016.28      12151739.60      10531660.62
# Europe             14712278.68      14521868.46      14406415.94
# ...

# %%
#Displaying the selected Continent
df[df['Continent'].str.contains('North America')].head()
# Out:
#     Rank CCA3    Country/Territory            Capital      Continent  \
# 6    224  AIA             Anguilla         The Valley  North America
# 7    201  ATG  Antigua and Barbuda  Saint JohnÃ¢ÂÂs  North America
# 10   198  ABW                Aruba         Oranjestad  North America
# 14   176  BHS              Bahamas             Nassau  North America
# 17   186  BRB             Barbados         Bridgetown  North America
#
#     2022 Population  2020 Population  2015 Population  2010 Population  \
# 6             15857            15585            14525            13172
# 7             93763            92664            89941            85695
# 10           106445           106585           104257           100341
# 14           409984           406471           392697           373272
# 17           281635           280693           278083           274711
#
#     2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
df2=df.groupby('Continent')[['1970 Population','2000 Population','2010 Population','2015 Population','2020 Population','2022 Population']].mean('numeric').sort_values(by='2022 Population', ascending=False)

# %%
df2
# Out:
#                1970 Population  2000 Population  2010 Population  \
# Continent
# Asia               42898125.80      74701792.08      84400826.54
# South America      13781939.71      24973877.29      28077017.86
# Africa              6411304.35      14367474.25      18512773.19
# North America       7885865.15      12151739.60      13568016.28
# Europe             13118479.82      14521868.46      14712278.68
# Oceania              846968.26       1357512.09       1613163.65
#
#                2015 Population  2020 Population  2022 Population
# Continent
# Asia               89165003.64      93261730.70      94427665.48
# South America      29509599.71      30823574.50      31201186.29
# Africa             21071972.67      23871435.26      25030367.23
# North America      14259596.25      14855914.82      15007403.40
# Europe             14830712.16      14915843.92      14862950.76
# Oceania             1756664.48       1910148.96       1958198.00

# %%
# Switching Column to Index and vice-versa
df3=df2.transpose()
df3
# Out:
# Continent              Asia  South America      Africa  North America  \
# 1970 Population 42898125.80    13781939.71  6411304.35     7885865.15
# 2000 Population 74701792.08    24973877.29 14367474.25    12151739.60
# 2010 Population 84400826.54    28077017.86 18512773.19    13568016.28
# 2015 Population 89165003.64    29509599.71 21071972.67    14259596.25
# 2020 Population 93261730.70    30823574.50 23871435.26    14855914.82
# 2022 Population 94427665.48    31201186.29 25030367.23    15007403.40
#
# Continent            Europe    Oceania
# 1970 Population 13118479.82  846968.26
# 2000 Population 14521868.46 1357512.09
# 2010 Population 14712278.68 1613163.65
# 2015 Population 14830712.16 1756664.48
# 2020 Population 14915843.92 1910148.96
# 2022 Population 14862950.76 1958198.00

# %%
plt.rcParams['figure.figsize']=(15,7)
df3.plot()
# Out:
# <Axes: >

# %%
df4=df[['Rank','Country/Territory','2022 Population','World Population Percentage']].sort_values('2022 Population',ascending=False)
df4.head()
# Out:
#      Rank Country/Territory  2022 Population  World Population Percentage
# 41      1             China       1425887337                        17.88
# 92      2             India       1417173173                        17.77
# 221     3     United States        338289857                         4.24
# 93      4         Indonesia        275501339                         3.45
# 156     5          Pakistan        235824862                         2.96

# %%
df[['Rank','1970 Population','2000 Population','2010 Population','2020 Population','2022 Population','World Population Percentage','Growth Rate']].corr()
# Out:
#                              Rank  1970 Population  2000 Population  \
# Rank                         1.00            -0.34            -0.34
# 1970 Population             -0.34             1.00             0.99
# 2000 Population             -0.34             0.99             1.00
# 2010 Population             -0.35             0.98             1.00
# 2020 Population             -0.36             0.98             1.00
# 2022 Population             -0.36             0.97             0.99
# World Population Percentage -0.36             0.97             0.99
# Growth Rate                 -0.22            -0.08            -0.05
#
#                              2010 Population  2020 Population  \
# Rank                                   -0.35            -0.36
# 1970 Population                         0.98             0.98
# 2000 Population                         1.00             1.00
# 2010 Population                         1.00             1.00
# ...

# %%
sns.heatmap(df[['Rank','1970 Population','2000 Population','2010 Population','2020 Population','2022 Population','World Population Percentage','Growth Rate']].corr(),annot=True)
# Out:
# <Axes: >
